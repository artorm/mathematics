# %%
# %matplotlib inline
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
import itertools

# %% [markdown]
# # Задача 1.
# Напишите код, моделирующий выпадение поля в рулетке (с учетом поля зеро).

# %%
for i in range(0,10):
    a= input()
    x= np.random.uniform(-1,36)
    if math.ceil(x) % 2 == 0:
        print(math.ceil(x), "Черное")
    elif math.ceil(x) % 2 != 0:
        print(math.ceil(x), "Красное")
    elif math.ceil(x) == 0:
        print(math.ceil(x), "Зеро")
    else:
        print(" Дабл Зеро")
# Out:
# 15 Красное
#
# 32 Черное
#
# 27 Красное
#
# 5 Красное
#
# 16 Черное
#
# 31 Красное
#
# 12 Черное
#
# 5 Красное
#
# 14 Черное
#
# 11 Красное

# %% [markdown]
# # Задача 2.
# 1.Напишите код, проверяющий любую из теорем сложения или умножения вероятности на примере рулетки или подбрасывания монетки.

# %%
a, b=0,0
c,d =0,0
n= 1000
for i in range(0,n):
    x = np.random.uniform(0,10)
    y = np.random.uniform(0,10)
    if x<5:
        a =a+1
        #print("Орел")
    if y<5:
        #print("Орел")
        b= b+1
    if x<5 and y<5:
        c=c+1
    if x<5 or y<5:
        d=d+1
print(a/n,b/n,c/n, d/n)
# Out:
# 0.496 0.486 0.236 0.746

# %% [markdown]
# #
# 2. Сгенерируйте десять выборок случайных чисел х0, …, х9 и постройте гистограмму распределения случайной суммы х0+х1+ …+ х9.

# %%
x = np.arange(0, 10, 1)
y = []

for i in range(0,10):
    y.append(sum(np.random.randint(-100, 100, size = 10)))

fig, ax = plt.subplots()


ax.bar(x, y)

fig.set_figwidth(12)    
fig.set_figheight(10)    
fig.set_facecolor('floralwhite')
ax.set_facecolor('seashell')

plt.show()

# %% [markdown]
# # Задание 3
# 1. Дополните код Монте-Карло последовательности независимых испытаний расчетом соответствующих вероятностей (через биномиальное распределение)
# и сравните результаты.

# %%
k, n =0, 10000
a =np.random.randint(0, 2, n)
b =np.random.randint(0, 2, n)
c =np.random.randint(0, 2, n)
d =np.random.randint(0, 2, n)
x = a+b+c+d

for i in range(0, n):
    if x[i]==2:
        k=k+1
        
C= math.factorial(4)/(math.factorial(4)*math.factorial(4-2))        
P=C*(1/(2**4))  

print(k, n, k/n ,P)
# Out:
# 3817 10000 0.3817 0.03125

# %% [markdown]
# #
# 2. Повторите расчеты биномиальных коэффициентов и вероятностей k успехов в последовательности из n независимых испытаний, взяв другие значения n и k.

# %%
k, n =0, 10000
a =np.random.randint(0, 2, n)
b =np.random.randint(0, 2, n)
c =np.random.randint(0, 2, n)
d =np.random.randint(0, 2, n)
e =np.random.randint(0, 2, n)
f =np.random.randint(0, 2, n)
x = a+b+c+d+e+f

for i in range(0, n):
    if x[i]==3:
        k=k+1
        
C= math.factorial(6)/(math.factorial(3)*math.factorial(6-3))        
P=C*(1/(2**6))  

print(k, n, k/n ,P)
# Out:
# 3127 10000 0.3127 0.3125

# %% [markdown]
# # Задача 4.
# Из урока по комбинаторике повторите расчеты, сгенерировав возможные варианты перестановок для других значений n и k

# %%
for p in itertools.combinations("0123456789",3):
    print(''.join(str(x) for x in p))
# Out:
# 012
# 013
# 014
# 015
# 016
# 017
# 018
# 019
# 023
# 024
# 025
# 026
# 027
# 028
# 029
# 034
# 035
# 036
# 037
# 038
# 039
# 045
# 046
# 047
# 048
# 049
# 056
# 057
# 058
# 059
# 067
# 068
# 069
# 078
# 079
# 089
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 134
# 135
# 136
# 137
# 138
# 139
# 145
# 146
# 147
# 148
# 149
# 156
# 157
# 158
# 159
# 167
# 168
# 169
# 178
# 179
# 189
# 234
# 235
# 236
# 237
# 238
# 239
# 245
# 246
# 247
# 248
# 249
# 256
# 257
# 258
# 259
# 267
# 268
# 269
# 278
# 279
# 289
# 345
# 346
# 347
# 348
# 349
# 356
# 357
# 358
# 359
# 367
# 368
# 369
# 378
# 379
# 389
# 456
# 457
# 458
# 459
# 467
# 468
# 469
# 478
# 479
# 489
# 567
# 568
# 569
# 578
# 579
# 589
# 678
# 679
# 689
# 789

# %%
for p in itertools.permutations("0123456789",3):
    print(''.join(str(x) for x in p))
# Out:
# 012
# 013
# 014
# 015
# 016
# 017
# 018
# 019
# 021
# 023
# 024
# 025
# 026
# 027
# 028
# 029
# 031
# 032
# 034
# 035
# 036
# 037
# 038
# 039
# 041
# 042
# 043
# 045
# 046
# 047
# 048
# 049
# 051
# 052
# 053
# 054
# 056
# 057
# 058
# 059
# 061
# 062
# 063
# 064
# 065
# 067
# 068
# 069
# 071
# 072
# 073
# 074
# 075
# 076
# 078
# 079
# 081
# 082
# 083
# 084
# 085
# 086
# 087
# 089
# 091
# 092
# 093
# 094
# 095
# 096
# 097
# 098
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 120
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 132
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 142
# 143
# 145
# 146
# 147
# 148
# 149
# 150
# 152
# 153
# 154
# 156
# 157
# 158
# 159
# 160
# 162
# 163
# 164
# 165
# 167
# 168
# 169
# 170
# 172
# 173
# 174
# 175
# 176
# 178
# 179
# 180
# 182
# 183
# 184
# 185
# 186
# 187
# 189
# 190
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 201
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 230
# 231
# 234
# 235
# 236
# 237
# ...

# %% [markdown]
# # Задание 5
#  Дополните код расчетом коэффициента корреляции x и y по формуле

# %%
n =100
r =0.7
x = np.random.rand(n)
y = r*x+(1-r)*np.random.rand(n)
plt.plot(x,y, 'o')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

a = (np.sum(x)*np.sum(y)-n*np.sum(x*y))/(np.sum(x)*np.sum(x)-n*np.sum(x*x))
b = (np.sum(y) -a*np.sum(x))/n



A =np.vstack([x, np.ones(len(x))]).T

a1, b1 = np.linalg.lstsq(A,y)[0]
print(a,b)
print(a1,b1)
plt.plot([0,1],[b,a+b])
plt.show()
print(np.corrcoef(x,y))
x_m= np.sum(x)/n
y_m= np.sum(y)/n
x1= x -x_m
y1= y -y_m
R= np.sum(x1*y1)/math.sqrt(np.sum(x1**2)* np.sum(y1**2))
print(x_m, y_m, R)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
# 0.6900020373276363 0.15609584077094588
# 0.6900020373276364 0.1560958407709457
# [[1.         0.91405615]
#  [0.91405615 1.        ]]
# 0.5527654343535807 0.5375051166392124 0.9140561524962424
